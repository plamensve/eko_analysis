# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from streamlit import columns

# %%
data = pd.read_excel('transport_data.xlsx')
data
# Out:
#              ДАТА  КУРС_ДАТА  \
# 0   20260127-0001 2026-01-26
# 1   20260127-0002 2026-01-27
# 2   20260127-0003 2026-01-28
# 3   20260128-0001 2026-01-29
# 4   20260129-0001 2026-01-30
# ..            ...        ...
# 76  20260327-0006 2026-03-27
# 77  20260330-0001 2026-03-30
# 78  20260330-0002 2026-03-30
# 79  20260330-0003 2026-03-31
# 80  20260304-0010 2026-03-04
#
#                                                  КУРС МАРШРУТ_СНИМКА  \
# 0                                    Русе-Тервел-Русе            NaN
# 1                                  Варна-Риш-Нефтохим            NaN
# 2        Нефтохим-Варна-Добрич-Караплит-Подайва-Варна            NaN
# 3                                   Варна-Шабла-Варна            NaN
# 4                    Варна-НХК-Повеляново-Добрич-Русе            NaN
# ..                                                ...            ...
# 76                             Варна-Повеляново-Варна            NaN
# 77  Бяла-Вълчи дол-Ген. Киселово-Стожер-Добрич-Тер...            NaN
# 78               Варна-Бяла-Русе-Добрич-Каварна-Варна            NaN
# 79                           Варна-Девня-Добрич-Варна            NaN
# 80                                Варна-Сенокос-Варна            NaN
#
#              ПРЕВОЗВАЧ                    ШОФЬОР    ВЛЕКАЧ ЦИСТЕРНА     КМ  \
# 0   ЕВРОУЕЙ СЪРВИЗ ООД      ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  300.0
# 1   ЕВРОУЕЙ СЪРВИЗ ООД     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  250.0
# 2   ЕВРОУЕЙ СЪРВИЗ ООД     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  420.0
# 3   ЕВРОУЕЙ СЪРВИЗ ООД     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА      NaN  180.0
# 4   ЕВРОУЕЙ СЪРВИЗ ООД      ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  560.0
# ..                 ...                       ...       ...      ...    ...
# 76  ЕВРОУЕЙ СЪРВИЗ ООД     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ   60.0
# 77  ЕВРОУЕЙ СЪРВИЗ ООД      ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  530.0
# 78  ЕВРОУЕЙ СЪРВИЗ ООД     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  580.0
# 79  ЕВРОУЕЙ СЪРВИЗ ООД     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  150.0
# 80      ТРАНС ОЙЛ ЕООД  ДИАН СТОЯНОВ АЛЕКСАНДРОВ  CB2201CC  P2849EE  160.0
#
#         Л  ...  ТОЛ_РАЗХОДИ  ЗАРЕДЕНО_ГОРИВО  ДРУГИ_РАЗХОДИ         СЪЗДАТЕЛ  \
# 0   32000  ...          NaN              NaN            NaN  Vesela Nikolova
# 1   19100  ...          NaN              NaN            NaN  Vesela Nikolova
# 2   31700  ...          NaN              NaN            NaN  Vesela Nikolova
# 3   18000  ...          NaN              NaN            NaN  Vesela Nikolova
# 4   30000  ...          NaN              NaN            NaN  Vesela Nikolova
# ..    ...  ...          ...              ...            ...              ...
# 76  11000  ...          NaN              NaN            NaN  Vesela Nikolova
# 77  32000  ...          NaN              NaN            NaN  Vesela Nikolova
# 78  30000  ...          NaN              NaN            NaN  Vesela Nikolova
# 79  34000  ...          NaN              NaN            NaN  Vesela Nikolova
# 80  18000  ...          NaN              NaN            NaN  Vesela Nikolova
#
#               СЪЗДАДЕНО_НА          ПРОМЯНА_ОТ         ПОСЛЕДЕН_ЪПДЕЙТ  \
# 0  2026-01-27 07:48:35.139  Plamen Svetoslavov 2026-02-26 12:03:29.540
# 1  2026-01-27 16:36:41.699  Plamen Svetoslavov 2026-02-01 08:23:26.349
# 2  2026-01-27 16:39:22.266     Vesela Nikolova 2026-01-27 16:41:33.200
# 3  2026-01-28 15:39:15.844     Vesela Nikolova 2026-01-28 15:41:35.766
# 4  2026-01-29 11:09:16.459     Vesela Nikolova 2026-01-29 11:11:21.095
# ..                     ...                 ...                     ...
# 76 2026-03-27 09:41:17.036     Vesela Nikolova 2026-03-27 09:43:12.499
# 77 2026-03-30 09:24:52.870     Vesela Nikolova 2026-03-30 09:27:41.051
# 78 2026-03-30 09:27:45.625     Vesela Nikolova 2026-03-30 09:29:15.621
# 79 2026-03-30 09:29:29.592     Vesela Nikolova 2026-03-30 09:32:22.022
# 80 2026-03-31 15:05:16.166  Plamen Svetoslavov 2026-03-31 15:11:44.834
#
#     ГОДИНА МЕСЕЦ ДЕН
# 0     2026     1  27
# 1     2026     1  27
# 2     2026     1  27
# 3     2026     1  28
# 4     2026     1  29
# ..     ...   ...  ..
# 76    2026     3  27
# 77    2026     3  30
# 78    2026     3  30
# 79    2026     3  30
# 80    2026     3   4
#
# [81 rows x 25 columns]

# %%
cleaned_data = data[['СЪЗДАТЕЛ', 'КУРС_ДАТА', 'КУРС', 'ПРЕВОЗВАЧ', 'ШОФЬОР', 'ВЛЕКАЧ', 'ЦИСТЕРНА', 'КМ', 'Л', '€_ЦЕНА_ОБЩО', '€_ЦЕНА_ЗА_1000', 'ДЕН', 'МЕСЕЦ', 'ГОДИНА']]
cleaned_data = cleaned_data.rename(columns={'СЪЗДАТЕЛ': 'ТЪРГОВЕЦ'})
cleaned_data
# Out:
#            ТЪРГОВЕЦ  КУРС_ДАТА  \
# 0   Vesela Nikolova 2026-01-26
# 1   Vesela Nikolova 2026-01-27
# 2   Vesela Nikolova 2026-01-28
# 3   Vesela Nikolova 2026-01-29
# 4   Vesela Nikolova 2026-01-30
# ..              ...        ...
# 76  Vesela Nikolova 2026-03-27
# 77  Vesela Nikolova 2026-03-30
# 78  Vesela Nikolova 2026-03-30
# 79  Vesela Nikolova 2026-03-31
# 80  Vesela Nikolova 2026-03-04
#
#                                                  КУРС           ПРЕВОЗВАЧ  \
# 0                                    Русе-Тервел-Русе  ЕВРОУЕЙ СЪРВИЗ ООД
# 1                                  Варна-Риш-Нефтохим  ЕВРОУЕЙ СЪРВИЗ ООД
# 2        Нефтохим-Варна-Добрич-Караплит-Подайва-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 3                                   Варна-Шабла-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 4                    Варна-НХК-Повеляново-Добрич-Русе  ЕВРОУЕЙ СЪРВИЗ ООД
# ..                                                ...                 ...
# 76                             Варна-Повеляново-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 77  Бяла-Вълчи дол-Ген. Киселово-Стожер-Добрич-Тер...  ЕВРОУЕЙ СЪРВИЗ ООД
# 78               Варна-Бяла-Русе-Добрич-Каварна-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 79                           Варна-Девня-Добрич-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 80                                Варна-Сенокос-Варна      ТРАНС ОЙЛ ЕООД
#
#                       ШОФЬОР    ВЛЕКАЧ ЦИСТЕРНА     КМ      Л  €_ЦЕНА_ОБЩО  \
# 0       ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  300.0  32000        285.0
# 1      ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  250.0  19100        240.0
# 2      ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  420.0  31700        400.0
# 3      ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА      NaN  180.0  18000        153.0
# 4       ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  560.0  30000        532.0
# ..                       ...       ...      ...    ...    ...          ...
# 76     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ   60.0  11000         60.0
# 77      ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  530.0  32000        530.0
# 78     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  580.0  30000        580.0
# 79     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  150.0  34000        150.0
# 80  ДИАН СТОЯНОВ АЛЕКСАНДРОВ  CB2201CC  P2849EE  160.0  18000        143.0
#
#     €_ЦЕНА_ЗА_1000  ДЕН  МЕСЕЦ  ГОДИНА
# 0         8.906250   27      1    2026
# 1        12.565445   27      1    2026
# 2        12.618297   27      1    2026
# 3         8.500000   28      1    2026
# 4        17.733333   29      1    2026
# ..             ...  ...    ...     ...
# 76        5.454545   27      3    2026
# 77       16.562500   30      3    2026
# 78       19.333333   30      3    2026
# 79        4.411765   30      3    2026
# 80        7.944444    4      3    2026
#
# [81 rows x 14 columns]

# %%
cleaned_data.to_csv('transport_data.csv', index=False)

# %%
cleaned_data = pd.read_csv('transport_data.csv')
cleaned_data
# Out:
#            ТЪРГОВЕЦ   КУРС_ДАТА  \
# 0   Vesela Nikolova  2026-01-26
# 1   Vesela Nikolova  2026-01-27
# 2   Vesela Nikolova  2026-01-28
# 3   Vesela Nikolova  2026-01-29
# 4   Vesela Nikolova  2026-01-30
# ..              ...         ...
# 76  Vesela Nikolova  2026-03-27
# 77  Vesela Nikolova  2026-03-30
# 78  Vesela Nikolova  2026-03-30
# 79  Vesela Nikolova  2026-03-31
# 80  Vesela Nikolova  2026-03-04
#
#                                                  КУРС           ПРЕВОЗВАЧ  \
# 0                                    Русе-Тервел-Русе  ЕВРОУЕЙ СЪРВИЗ ООД
# 1                                  Варна-Риш-Нефтохим  ЕВРОУЕЙ СЪРВИЗ ООД
# 2        Нефтохим-Варна-Добрич-Караплит-Подайва-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 3                                   Варна-Шабла-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 4                    Варна-НХК-Повеляново-Добрич-Русе  ЕВРОУЕЙ СЪРВИЗ ООД
# ..                                                ...                 ...
# 76                             Варна-Повеляново-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 77  Бяла-Вълчи дол-Ген. Киселово-Стожер-Добрич-Тер...  ЕВРОУЕЙ СЪРВИЗ ООД
# 78               Варна-Бяла-Русе-Добрич-Каварна-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 79                           Варна-Девня-Добрич-Варна  ЕВРОУЕЙ СЪРВИЗ ООД
# 80                                Варна-Сенокос-Варна      ТРАНС ОЙЛ ЕООД
#
#                       ШОФЬОР    ВЛЕКАЧ ЦИСТЕРНА     КМ      Л  €_ЦЕНА_ОБЩО  \
# 0       ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  300.0  32000        285.0
# 1      ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  250.0  19100        240.0
# 2      ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  420.0  31700        400.0
# 3      ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА      NaN  180.0  18000        153.0
# 4       ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  560.0  30000        532.0
# ..                       ...       ...      ...    ...    ...          ...
# 76     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ   60.0  11000         60.0
# 77      ДАНИЕЛ ПЕНЧЕВ ПЕНЧЕВ   Р7826КН  Р2530ЕЕ  530.0  32000        530.0
# 78     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  580.0  30000        580.0
# 79     ГЕОРГИ ИЛИЕВ ГЕОРГИЕВ   Р9581МА  Р4961ЕЕ  150.0  34000        150.0
# 80  ДИАН СТОЯНОВ АЛЕКСАНДРОВ  CB2201CC  P2849EE  160.0  18000        143.0
#
#     €_ЦЕНА_ЗА_1000  ДЕН  МЕСЕЦ  ГОДИНА
# 0         8.906250   27      1    2026
# 1        12.565445   27      1    2026
# 2        12.618297   27      1    2026
# 3         8.500000   28      1    2026
# 4        17.733333   29      1    2026
# ..             ...  ...    ...     ...
# 76        5.454545   27      3    2026
# 77       16.562500   30      3    2026
# 78       19.333333   30      3    2026
# 79        4.411765   30      3    2026
# 80        7.944444    4      3    2026
#
# [81 rows x 14 columns]

# %%
mean_km = round(cleaned_data['КМ'].mean(), 2)
mean_liters = round(cleaned_data['Л'].mean(), 2)
mean_price_total = round(cleaned_data['€_ЦЕНА_ОБЩО'].mean(), 2)
mean_price_per_1000 = round(cleaned_data['€_ЦЕНА_ЗА_1000'].mean(), 2)
mean_price_per_1000
# Out:
# np.float64(12.71)
